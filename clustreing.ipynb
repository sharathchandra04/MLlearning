# %% [markdown]
# <a href="https://colab.research.google.com/github/sharathchandra04/MLlearning/blob/main/clustreing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem 4 (20 Points): Generating GMMs
# In this problem, you will write code to generate a mixture of 3 Gaussians satisfying the following requirements,
# respectively. Please specify the mean vector and covariance matrix of each Gaussian in your answer.

# %% [markdown]
# 1. 6 Points. Draw a data set where a mixture of 3 spherical Gaussians (where the covariance matrix is
# the identity matrix times some positive scalar) can model the data well, but K-means cannot.

# %%
import tensorflow as tf
import tensorflow_probability as tfp
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt

plt.grid()
plt.xlim([-15, 15])
plt.ylim([-15, 15])
spherical_1 = tfp.distributions.MultivariateNormalDiag(loc=[8.0, 5.0], scale_diag=[1, 1])
data_spherical = spherical_1.sample(500)
plt.scatter(data_spherical[:, 0], data_spherical[:, 1])
spherical_2 = tfp.distributions.MultivariateNormalDiag(loc=[0, 0],scale_diag=[2, 2])
data_spherical_2 = spherical_2.sample(500)
plt.scatter(data_spherical_2[:, 0], data_spherical_2[:, 1])
spherical_3 = tfp.distributions.MultivariateNormalDiag(loc=[-8.0, -8.0],scale_diag=[3, 3])
data_spherical_3 = spherical_3.sample(500)
plt.scatter(data_spherical_3[:, 0], data_spherical_3[:, 1],)

# %%
plt.grid()
plt.xlim([-15, 15])
plt.ylim([-15, 15])
diag1 = tfp.distributions.MultivariateNormalDiag(loc=[-10, 10], scale_diag=[1.0, 1.0])
data_diag1 = diag1.sample(500)
plt.scatter(data_diag1[:, 0], data_diag1[:, 1])
diag2 = tfp.distributions.MultivariateNormalDiag(loc=[-5, -5], scale_diag=[2.0, 2.0])
data_diag2 = diag2.sample(500)
plt.scatter(data_diag2[:, 0], data_diag2[:, 1])
diag3 = tfp.distributions.MultivariateNormalDiag(loc=[5, 5], scale_diag=[3.0, 3.0])
data_diag3 = diag3.sample(500)
plt.scatter(data_diag3[:, 0], data_diag3[:, 1])

# %%
plt.grid()
plt.xlim([-10, 12])
plt.ylim([-10, 12])
full1 = tfp.distributions.MultivariateNormalFullCovariance(loc=[7, 7])
data_full1 = full1.sample(500)
plt.scatter(data_full1[:, 0], data_full1[:, 1])
full2 = tfp.distributions.MultivariateNormalFullCovariance(loc=[2, 2])
data_full2 = full2.sample(500)
plt.scatter(data_full2[:, 0], data_full2[:, 1])
full3 = tfp.distributions.MultivariateNormalFullCovariance(loc=[-5, -5])
data_full3 = full3.sample(500)
plt.scatter(data_full3[:, 0], data_full3[:, 1])
